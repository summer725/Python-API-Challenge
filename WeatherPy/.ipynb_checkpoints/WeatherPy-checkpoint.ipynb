# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %%
cities
# Out:
# ['hobart',
#  'kazachinskoye',
#  'galgani',
#  'denpasar',
#  'illoqqortoormiut',
#  'busselton',
#  'luderitz',
#  'louisbourg',
#  'butaritari',
#  'mahebourg',
#  'yellowknife',
#  'maragogi',
#  'ancud',
#  'hermanus',
#  'faanui',
#  'mataura',
#  'asosa',
#  'kapaa',
#  'vaini',
#  'kokopo',
#  'avera',
#  'east london',
#  'roald',
#  'atambua',
#  'dikson',
#  'kahului',
#  'khatanga',
#  'alofi',
#  'chokurdakh',
#  'cape town',
#  'port alfred',
#  'pundaguitan',
#  'namibe',
#  'matai',
#  'labutta',
#  'hilo',
#  'mount isa',
#  'esperance',
#  'ushuaia',
#  'tuktoyaktuk',
#  'attawapiskat',
#  'punta arenas',
#  'rikitea',
#  'pisco',
#  'norman wells',
#  'barentsburg',
#  'puerto ayora',
#  'longyearbyen',
#  'yulara',
#  'bluff',
#  'udachnyy',
#  'dicabisagan',
#  'harrison',
#  'egvekinot',
#  'maldonado',
#  'west wendover',
#  'provideniya',
#  'san cristobal',
#  'baiyin',
#  'saskylakh',
#  'brae',
#  'inhambane',
#  'poum',
#  'zhanatas',
#  'kroya',
#  'lashio',
#  'qaanaaq',
#  'westport',
#  'oranjemund',
#  'atuona',
#  'port hardy',
#  'warrnambool',
#  'hasaki',
#  'arraial do cabo',
#  'taolanaro',
#  'mar del plata',
#  'kontagora',
#  'rio pomba',
#  'amderma',
#  'ilulissat',
#  'caravelas',
#  'tikrit',
#  'nanortalik',
#  'umm lajj',
#  'dudinka',
#  'tubruq',
#  'jamestown',
#  'talkha',
#  'tynda',
#  'negombo',
#  'buenos aires',
#  'nikolskoye',
#  'campo grande',
#  'los llanos de aridane',
#  'ketchikan',
#  'turukhansk',
#  'sao joao da barra',
#  'bandarbeyla',
#  'komsomolskiy',
#  'dawlatabad',
#  'samusu',
#  'samalaeulu',
#  'new norfolk',
#  'ahipara',
#  'castro',
#  'albany',
#  'xinzhi',
#  'hithadhoo',
#  'erenhot',
#  'ullal',
#  'clyde river',
#  'kolokani',
#  'vargem grande do sul',
#  'kununurra',
#  'kodiak',
#  'pontianak',
#  'lolua',
#  'iqaluit',
#  'novikovo',
#  'upernavik',
#  'urucara',
#  'nador',
#  'bredasdorp',
#  'midland',
#  'bad aussee',
#  'narsaq',
#  'nouadhibou',
#  'filingue',
#  'dingle',
#  'kovdor',
#  'saint-louis',
#  'constitucion',
#  'sussex',
#  'sabha',
#  'tiznit',
#  'khandyga',
#  'sretensk',
#  'montijo',
#  'narasannapeta',
#  'sitka',
#  'moen',
#  'qaqortoq',
#  'mehran',
#  'severo-kurilsk',
#  'balimo',
#  'san patricio',
#  'port elizabeth',
#  'sentyabrskiy',
#  'kaitangata',
#  'delta del tigre',
#  'airai',
#  'tamandare',
#  'stabat',
#  'ponta delgada',
#  'lebu',
#  'mys shmidta',
#  'thompson',
#  'teguise',
#  'dwarka',
#  'gamba',
#  'vaitupu',
#  'pangnirtung',
#  'ponta do sol',
#  'kifri',
#  'barrow',
#  'cherskiy',
#  'pak phanang',
#  'sindor',
#  'salta',
#  'taksimo',
#  'miyako',
#  'kapuskasing',
#  'rawson',
#  'matara',
#  'cidreira',
#  'lagoa',
#  'vila franca do campo',
#  'dongsheng',
#  'gornopravdinsk',
#  'sao filipe',
#  'calbuco',
#  'phangnga',
#  'manyana',
#  'jalu',
#  'sola',
#  'bengkulu',
#  'rantauprapat',
#  'talnakh',
#  'skelleftea',
#  'abu kamal',
#  'san quintin',
#  'isangel',
#  'gunjur',
#  'pingliang',
#  'sedelnikovo',
#  'cuamba',
#  'campbell river',
#  'palembang',
#  'vallenar',
#  'bambous virieux',
#  'pizarro',
#  'zhezkazgan',
#  'bam',
#  'ostrovnoy',
#  'kruisfontein',
#  'cabucgayan',
#  'pacifica',
#  'mananara',
#  'san pedro',
#  'bethel',
#  'avarua',
#  'leshukonskoye',
#  'prescott',
#  'woodward',
#  'winnemucca',
#  'darnah',
#  'contamana',
#  'belushya guba',
#  'cabo san lucas',
#  'iquitos',
#  'saint-philippe',
#  'tiksi',
#  'kenitra',
#  'bloomingdale',
#  'curup',
#  'hunza',
#  'georgetown',
#  'leningradskiy',
#  'poronaysk',
#  'neuquen',
#  'the valley',
#  'tsihombe',
#  'ribeira grande',
#  'lompoc',
#  'palabuhanratu',
#  'mount gambier',
#  'kavieng',
#  'bosobolo',
#  'cartagena',
#  'raudeberg',
#  'torbay',
#  'changping',
#  'formoso do araguaia',
#  'peto',
#  'banda aceh',
#  'venado tuerto',
#  'boa vista',
#  'kisac',
#  'ekhabi',
#  'cockburn harbour',
#  'snyder',
#  'sambava',
#  'grand river south east',
#  'acajutla',
#  'conceicao da barra',
#  'dhidhdhoo',
#  'khonuu',
#  'dubbo',
#  'aykhal',
#  'ardabil',
#  'yunjinghong',
#  'souillac',
#  'tepechitlan',
#  'ous',
#  'katsuura',
#  'berlevag',
#  'manzil jamil',
#  'harper',
#  'pimentel',
#  'beya',
#  'vao',
#  'luena',
#  'mabaruma',
#  'tabas',
#  'novokayakent',
#  'lima',
#  'touros',
#  'suntar',
#  'siniscola',
#  'vigrestad',
#  'novoagansk',
#  'deyang',
#  'iacobeni',
#  'cockburn town',
#  'mandan',
#  'yuzhno-yeniseyskiy',
#  'deputatskiy',
#  'nizhneyansk',
#  'kulhudhuffushi',
#  'umea',
#  'tilichiki',
#  'deniliquin',
#  'grand gaube',
#  'mangan',
#  'tasiilaq',
#  'aloleng',
#  'itarema',
#  'marcona',
#  'kaeo',
#  'ilinskiy',
#  'myrtle beach',
#  'asyut',
#  'itupiranga',
#  'bernay',
#  'samarinda',
#  'vestbygda',
#  'vilyuysk',
#  'fairbanks',
#  'raver',
#  'fortuna',
#  'george town',
#  'merauke',
#  'biak',
#  'boende',
#  'lata',
#  'karaul',
#  'nam tha',
#  'walvis bay',
#  'george',
#  'port blair',
#  'karpathos',
#  'port moresby',
#  'san ramon de la nueva oran',
#  'san javier',
#  'plastunovskaya',
#  'manali',
#  'coquimbo',
#  'kalispell',
#  'sorong',
#  'nishihara',
#  'mehamn',
#  'kenai',
#  'dharmavaram',
#  'tuatapere',
#  'hami',
#  'harnosand',
#  'padang',
#  'vanimo',
#  'markapur',
#  'buala',
#  'manono',
#  'dalvik',
#  'petropavlovsk-kamchatskiy',
#  'minna',
#  'goderich',
#  'mitu',
#  'bahia blanca',
#  'longlac',
#  'muroto',
#  'vorontsovka',
#  'vila',
#  'cayhagan',
#  'saint-augustin',
#  'klaksvik',
#  'cajabamba',
#  'camacha',
#  'paramirim',
#  'general roca',
#  'tezu',
#  'birao',
#  'ngunguru',
#  'samarai',
#  'fort nelson',
#  'richards bay',
#  'victoria',
#  'alotau',
#  'envira',
#  'srednekolymsk',
#  'yambio',
#  'lorengau',
#  'thinadhoo',
#  'lavrentiya',
#  'ossora',
#  'vestmannaeyjar',
#  'daru',
#  'mtwango',
#  'codajas',
#  'aswan',
#  'vila velha',
#  'qostanay',
#  'mayo',
#  'hamilton',
#  'carballo',
#  'eyl',
#  'acapulco',
#  'hue',
#  'peniche',
#  'bilma',
#  'jiutai',
#  'maulvi bazar',
#  'itaituba',
#  'saleaula',
#  'carnarvon',
#  'hun',
#  'oistins',
#  'havre-saint-pierre',
#  'batemans bay',
#  'kuloy',
#  'salalah',
#  'dukat',
#  'novopokrovka',
#  'byron bay',
#  'quang ngai',
#  'aracati',
#  'reconquista',
#  'saint-pierre',
#  'saint anthony',
#  'mantua',
#  'mingshui',
#  'republic',
#  'atar',
#  'guajara',
#  'ayr',
#  'andenes',
#  'saqqez',
#  'valparaiso',
#  'codrington',
#  'korla',
#  'puerto carreno',
#  'geraldton',
#  'luneburg',
#  'teneguiban',
#  'meadow lake',
#  'a',
#  'olhao',
#  'lakshmeshwar',
#  'port-cartier',
#  'teluk intan',
#  'loviisa',
#  'sri aman',
#  'orahovac',
#  'chuy',
#  'sansai',
#  'viligili',
#  'aasiaat',
#  'gold coast',
#  'kamenskoye',
#  'pecos',
#  'ocampo',
#  'shelburne',
#  'timra',
#  'necochea',
#  'guna',
#  'namatanai',
#  'kavaratti',
#  'yeppoon',
#  'pevek',
#  'sarangani',
#  'diego de almagro',
#  'siderno',
#  'catio',
#  'saint george',
#  'van',
#  'shaki',
#  'jardim',
#  'olafsvik',
#  'nhulunbuy',
#  'visnes',
#  'mettur',
#  'nouakchott',
#  'jumla',
#  'callaway',
#  'la palma',
#  'koryazhma',
#  'kayes',
#  'hambantota',
#  'belyy yar',
#  'akdepe',
#  'sabang',
#  'killybegs',
#  'najran',
#  'pemba',
#  'kuche',
#  'rio grande',
#  'plettenberg bay',
#  'tawkar',
#  'tayoltita',
#  'arlit',
#  'kayankulam',
#  'santa rosa',
#  'margate',
#  'savannah bight',
#  'abu samrah',
#  'yerbogachen',
#  'saldanha',
#  'angoche',
#  'kudahuvadhoo',
#  'san jose',
#  'puerto pinasco',
#  'moose factory',
#  'santa maria',
#  'gazojak',
#  'okhotsk',
#  'sursee',
#  'valday',
#  'puerto escondido',
#  'vardo',
#  'fukue',
#  'karratha',
#  'port-gentil',
#  'tomatlan',
#  'saint-georges',
#  'sredec',
#  'satitoa',
#  'buqayq',
#  'marion',
#  'sturgeon bay',
#  'huntsville',
#  'vila do maio',
#  'isiro',
#  'limulunga',
#  'bay roberts',
#  'waipawa',
#  'novyy urengoy',
#  'northam',
#  'semirom',
#  'atasu',
#  'banamba',
#  'khabary',
#  'kieta',
#  'mergui',
#  'sept-iles',
#  'inverness',
#  'helong',
#  'upata',
#  'akyab',
#  'asayita',
#  'port keats',
#  'haibowan',
#  'namanga',
#  'mindelo',
#  'aquiraz',
#  'ordzhonikidze',
#  'boromo',
#  'mullaitivu',
#  'raga',
#  'buraydah',
#  'north platte',
#  'santa cruz',
#  'halalo',
#  'la rioja',
#  'wajima',
#  'mufulira',
#  'zalantun',
#  'vilcun',
#  'varhaug',
#  'jamame',
#  'banyo',
#  'palmer',
#  'trairi',
#  'hofn',
#  'campos altos',
#  'alice springs',
#  'balikpapan',
#  'xiongyue',
#  'voznesenye',
#  'pijijiapan',
#  'carbondale',
#  'bollnas',
#  'whitehorse',
#  'bushehr',
#  'blonduos',
#  'geghamasar',
#  'barillas',
#  'chudovo',
#  'hirara',
#  'caracoli',
#  'malabo',
#  'jagatsinghapur',
#  'faya',
#  'chapais',
#  'kousseri',
#  'tumannyy',
#  'paradwip',
#  'broome',
#  'gizo',
#  'lasa',
#  'tambun',
#  'crepy-en-valois',
#  'harboore',
#  'yagodnoye',
#  'kralendijk',
#  'muzhi',
#  'dunedin',
#  'mentok',
#  'rio tuba',
#  'nokaneng',
#  'porto novo',
#  'pacific grove',
#  'katobu',
#  'nikki',
#  'rungata',
#  'san carlos de bariloche',
#  'mishkino',
#  'neftcala',
#  'henties bay',
#  'paamiut',
#  'hengshui',
#  'roura',
#  'bafoulabe',
#  'roquetas de mar',
#  'tual',
#  'roma',
#  'yuancheng',
#  'salinopolis',
#  'camapua',
#  'roseburg',
#  'otterup',
#  'sioux lookout',
#  'boone']

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = ["metric", "imperial"]
query_url = f"{url}appid={weather_api_key}&units={units}&q="
query_url
# Out:
# "http://api.openweathermap.org/data/2.5/weather?appid=a2ea56a1e9bb9d6ba98adcdbcb2dcb5a&units=['metric', 'imperial']&q="

# %%
response = requests.get(query_url + city).json()
response
# Out:
# {'cod': '404', 'message': 'city not found'}

# %%
response.keys()
# Out:
# dict_keys(['cod', 'message'])

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
data = [] #empty list for the weather data
count = 0 #incremements
for city in cities:
    maps = requests.get(query_url + city).json()
    
    try: 
        weather_dict = {
            "City":maps['name'],
            "Latitude":maps["coord"]["lat"],
            "Longitude":maps["coord"]["lon"],
            "Max Temp":maps["main"]["temp_max"],
            "Humidity":maps["main"]["humidity"],
            "Clouds":maps["clouds"]["all"], 
            "Wind (in mph)":maps["wind"]["speed"],
            "Country":maps["sys"]["country"],
            "Date":maps["dt"]}
        
        data.append(weather_dict)
        count = count + 1 
        print(f"Processing {count}. {maps['name']}")
    except: 
        print("City Unknown. Skipping... ")

maps
# Out:
# Processing 1. Hobart
# Processing 2. Kazachinskoye
# City Unknown. Skipping...
# Processing 3. Denpasar
# City Unknown. Skipping...
# Processing 4. Busselton
# Processing 5. Lüderitz
# City Unknown. Skipping...
# Processing 6. Butaritari
# Processing 7. Mahébourg
# Processing 8. Yellowknife
# Processing 9. Maragogi
# Processing 10. Ancud
# Processing 11. Hermanus
# Processing 12. Faanui
# Processing 13. Mataura
# Processing 14. Āsosa
# Processing 15. Kapaa
# Processing 16. Vaini
# Processing 17. Kokopo
# Processing 18. Avera
# Processing 19. East London
# Processing 20. Roald
# Processing 21. Atambua
# Processing 22. Dikson
# Processing 23. Kahului
# Processing 24. Khatanga
# Processing 25. Alofi
# Processing 26. Chokurdakh
# Processing 27. Cape Town
# Processing 28. Port Alfred
# Processing 29. Pundaguitan
# Processing 30. Mossamedes
# Processing 31. Matai
# City Unknown. Skipping...
# Processing 32. Hilo
# Processing 33. Mount Isa
# Processing 34. Esperance
# Processing 35. Ushuaia
# Processing 36. Tuktoyaktuk
# City Unknown. Skipping...
# Processing 37. Punta Arenas
# Processing 38. Rikitea
# Processing 39. Pisco
# Processing 40. Norman Wells
# City Unknown. Skipping...
# Processing 41. Puerto Ayora
# Processing 42. Longyearbyen
# Processing 43. Yulara
# Processing 44. Bluff
# Processing 45. Udachny
# Processing 46. Dicabisagan
# Processing 47. Harrison
# Processing 48. Egvekinot
# Processing 49. Departamento de Maldonado
# Processing 50. West Wendover
# Processing 51. Provideniya
# Processing 52. San Cristobal
# Processing 53. Baiyin
# Processing 54. Saskylakh
# Processing 55. Brae
# Processing 56. Inhambane
# Processing 57. Poum
# City Unknown. Skipping...
# Processing 58. Kroya
# Processing 59. Lashio
# Processing 60. Qaanaaq
# Processing 61. Westport
# Processing 62. Oranjemund
# Processing 63. Atuona
# Processing 64. Port Hardy
# Processing 65. Warrnambool
# Processing 66. Hasaki
# Processing 67. Arraial do Cabo
# City Unknown. Skipping...
# Processing 68. Mar del Plata
# Processing 69. Kontagora
# Processing 70. Rio Pomba
# City Unknown. Skipping...
# Processing 71. Ilulissat
# Processing 72. Caravelas
# Processing 73. Tikrit
# Processing 74. Nanortalik
# Processing 75. Umluj
# Processing 76. Dudinka
# City Unknown. Skipping...
# Processing 77. Jamestown
# Processing 78. Ţalkhā
# Processing 79. Tynda
# Processing 80. Negombo
# Processing 81. Buenos Aires
# Processing 82. Nikolskoye
# Processing 83. Campo Grande
# Processing 84. Los Llanos de Aridane
# Processing 85. Ketchikan
# Processing 86. Turukhansk
# Processing 87. São João da Barra
# Processing 88. Bandarbeyla
# Processing 89. Yangi Marg`ilon
# Processing 90. Dawlatabad
# City Unknown. Skipping...
# City Unknown. Skipping...
# Processing 91. New Norfolk
# Processing 92. Ahipara
# Processing 93. Castro
# Processing 94. Albany
# Processing 95. Xinzhi
# Processing 96. Hithadhoo
# Processing 97. Erenhot
# Processing 98. Ullal
# Processing 99. Clyde River
# Processing 100. Kolokani
# Processing 101. Vargem Grande do Sul
# Processing 102. Kununurra
# Processing 103. Saint Paul Harbor
# Processing 104. Pontianak
# City Unknown. Skipping...
# Processing 105. Iqaluit
# Processing 106. Novikovo
# Processing 107. Upernavik
# Processing 108. Urucará
# Processing 109. Nador
# Processing 110. Bredasdorp
# Processing 111. Midland
# Processing 112. Bad Aussee
# Processing 113. Narsaq
# Processing 114. Nouadhibou
# Processing 115. Filingué
# Processing 116. Dingle
# Processing 117. Kovdor
# Processing 118. Saint-Louis
# Processing 119. Constitución
# Processing 120. Sussex
# Processing 121. Sabha
# Processing 122. Tiznit Province
# Processing 123. Khandyga
# Processing 124. Sretensk
# Processing 125. Montijo
# Processing 126. Narasannapeta
# Processing 127. Sitka
# Processing 128. Moen
# Processing 129. Qaqortoq
# Processing 130. Mehrān
# Processing 131. Severo-Kuril'sk
# City Unknown. Skipping...
# Processing 132. San Patricio
# Processing 133. Port Elizabeth
# City Unknown. Skipping...
# Processing 134. Kaitangata
# Processing 135. Delta del Tigre
# Processing 136. Airai
# Processing 137. Tamandaré
# Processing 138. Stabat
# Processing 139. Ponta Delgada
# Processing 140. Lebu
# City Unknown. Skipping...
# Processing 141. Thompson
# Processing 142. Teguise
# Processing 143. Dwārka
# Processing 144. Gamba
# City Unknown. Skipping...
# Processing 145. Pangnirtung
# Processing 146. Ponta do Sol
# Processing 147. Kifrī
# Processing 148. Barrow
# Processing 149. Cherskiy
# Processing 150. Pak Phanang
# Processing 151. Sindor
# Processing 152. Salta
# Processing 153. Taksimo
# Processing 154. Miyako
# Processing 155. Kapuskasing
# Processing 156. Rawson
# Processing 157. Matara
# Processing 158. Cidreira
# Processing 159. Lagoa
# Processing 160. Vila Franca do Campo
# Processing 161. Dongsheng
# Processing 162. Gornopravdinsk
# Processing 163. São Filipe
# Processing 164. Calbuco
# Processing 165. Phang Nga
# Processing 166. Manyana
# Processing 167. Jalu
# Processing 168. Sola
# Processing 169. Bengkulu
# Processing 170. Rantauprapat
# Processing 171. Talnakh
# Processing 172. Skellefteå
# Processing 173. Abu Kamal
# Processing 174. San Quintín
# Processing 175. Isangel
# Processing 176. Gunjur
# Processing 177. Pingliang
# City Unknown. Skipping...
# Processing 178. Cuamba
# Processing 179. Campbell River
# Processing 180. Palembang
# Processing 181. Vallenar
# Processing 182. Bambous Virieux
# Processing 183. Pizarro
# Processing 184. Zhezkazgan
# Processing 185. Bam
# Processing 186. Ostrovnoy
# Processing 187. Kruisfontein
# Processing 188. Cabucgayan
# Processing 189. Pacifica
# Processing 190. Mananara
# Processing 191. City of San Pedro
# Processing 192. Bethel
# Processing 193. Avarua
# Processing 194. Leshukonskoye
# Processing 195. Prescott
# Processing 196. Woodward
# Processing 197. Winnemucca
# Processing 198. Darnah
# Processing 199. Contamana
# City Unknown. Skipping...
# Processing 200. Cabo San Lucas
# Processing 201. Iquitos
# Processing 202. Saint-Philippe
# Processing 203. Tiksi
# Processing 204. Kenitra
# Processing 205. Bloomingdale
# Processing 206. Curup
# City Unknown. Skipping...
# Processing 207. George Town
# Processing 208. Leningradskiy
# Processing 209. Poronaysk
# Processing 210. Neuquén
# Processing 211. The Valley
# City Unknown. Skipping...
# Processing 212. Ribeira Grande
# Processing 213. Lompoc
# City Unknown. Skipping...
# Processing 214. Mount Gambier
# Processing 215. Kavieng
# Processing 216. Bosobolo
# Processing 217. Cartagena
# Processing 218. Raudeberg
# Processing 219. Torbay
# Processing 220. Changping
# City Unknown. Skipping...
# Processing 221. Peto
# Processing 222. Banda Aceh
# Processing 223. Venado Tuerto
# Processing 224. Boa Vista
# Processing 225. Kisač
# Processing 226. Ekhabi
# City Unknown. Skipping...
# Processing 227. Snyder
# Processing 228. Sambava
# City Unknown. Skipping...
# Processing 229. Acajutla
# Processing 230. Conceição da Barra
# Processing 231. Dhidhdhoo
# City Unknown. Skipping...
# Processing 232. Dubbo
# Processing 233. Aykhal
# Processing 234. Ardabil
# City Unknown. Skipping...
# Processing 235. Souillac
# Processing 236. Tepechitlán
# Processing 237. Ous
# Processing 238. Katsuura
# Processing 239. Berlevåg
# City Unknown. Skipping...
# Processing 240. Harper
# Processing 241. Pimentel
# Processing 242. Beya
# Processing 243. Vao
# Processing 244. Luena
# Processing 245. Mabaruma
# Processing 246. Tabas
# Processing 247. Novokayakent
# Processing 248. Lima
# Processing 249. Touros
# Processing 250. Suntar
# Processing 251. Siniscola
# Processing 252. Vigrestad
# Processing 253. Novoagansk
# Processing 254. Deyang
# Processing 255. Iacobeni
# Processing 256. Cockburn Town
# Processing 257. Mandan
# City Unknown. Skipping...
# Processing 258. Deputatsky
# City Unknown. Skipping...
# Processing 259. Kulhudhuffushi
# Processing 260. Umeå
# Processing 261. Tilichiki
# Processing 262. Deniliquin
# Processing 263. Grand Gaube
# Processing 264. Mangan
# Processing 265. Tasiilaq
# Processing 266. Aloleng
# Processing 267. Itarema
# City Unknown. Skipping...
# Processing 268. Kaeo
# Processing 269. Il’inskiy
# Processing 270. Myrtle Beach
# Processing 271. Assiut
# Processing 272. Itupiranga
# Processing 273. Arrondissement de Bernay
# Processing 274. Samarinda
# City Unknown. Skipping...
# Processing 275. Vilyuysk
# Processing 276. Fairbanks
# Processing 277. Rāver
# Processing 278. Fortuna
# Processing 279. George Town
# Processing 280. Merauke
# Processing 281. Biak
# Processing 282. Boende
# Processing 283. Lata
# City Unknown. Skipping...
# City Unknown. Skipping...
# Processing 284. Walvis Bay
# Processing 285. George
# Processing 286. Port Blair
# Processing 287. Karpathos
# Processing 288. Port Moresby
# Processing 289. Orán
# Processing 290. San Javier
# Processing 291. Plastunovskaya
# Processing 292. Manali
# Processing 293. Coquimbo
# Processing 294. Kalispell
# Processing 295. Sorong
# Processing 296. Nishihara
# Processing 297. Mehamn
# Processing 298. Kenai
# Processing 299. Dharmavaram
# Processing 300. Tuatapere
# Processing 301. Kumul
# Processing 302. Härnösand
# Processing 303. Padang
# Processing 304. Vanimo
# Processing 305. Mārkāpur
# Processing 306. Buala
# Processing 307. Manono
# Processing 308. Dalvik
# Processing 309. Petropavlovsk-Kamchatskiy
# Processing 310. Minna
# Processing 311. Goderich
# Processing 312. Mitú
# Processing 313. Bahía Blanca
# City Unknown. Skipping...
# Processing 314. Muroto-misakicho
# Processing 315. Vorontsovka
# Processing 316. Vila
# Processing 317. Cayhagan
# Processing 318. Saint-Augustin
# Processing 319. Klaksvík
# Processing 320. Cajabamba
# Processing 321. Camacha
# Processing 322. Paramirim
# Processing 323. General Roca
# Processing 324. Tezu
# Processing 325. Birao
# Processing 326. Ngunguru
# Processing 327. Samarai
# Processing 328. Fort Nelson
# Processing 329. Richards Bay
# Processing 330. Hong Kong
# City Unknown. Skipping...
# Processing 331. Envira
# Processing 332. Srednekolymsk
# Processing 333. Yambio
# Processing 334. Lorengau
# Processing 335. Thinadhoo
# Processing 336. Lavrentiya
# Processing 337. Ossora
# Processing 338. Vestmannaeyjar
# Processing 339. Daru
# Processing 340. Mtwango
# Processing 341. Codajás
# Processing 342. Aswān
# Processing 343. Vila Velha
# Processing 344. Kostanay
# Processing 345. Mayo
# Processing 346. Hamilton
# Processing 347. Carballo
# Processing 348. Eyl
# Processing 349. Acapulco de Juárez
# Processing 350. Hue
# Processing 351. Peniche
# Processing 352. Bilma
# Processing 353. Jiutai
# City Unknown. Skipping...
# Processing 354. Itaituba
# City Unknown. Skipping...
# Processing 355. Carnarvon
# Processing 356. Hūn
# Processing 357. Oistins
# Processing 358. Havre-St-Pierre
# Processing 359. Batemans Bay
# Processing 360. Kuloy
# Processing 361. Salalah
# Processing 362. Dukat
# Processing 363. Novopokrovka
# Processing 364. Byron Bay
# Processing 365. Quang Ngai
# Processing 366. Aracati
# Processing 367. Reconquista
# Processing 368. Saint-Pierre
# Processing 369. Saint Anthony
# Processing 370. Province of Mantua
# Processing 371. Mingshui
# Processing 372. Republic
# Processing 373. Atar
# Processing 374. Guajará
# Processing 375. Ayr
# Processing 376. Andenes
# Processing 377. Saqqez
# Processing 378. Valparaíso
# Processing 379. Codrington
# Processing 380. Korla
# Processing 381. Puerto Carreño
# Processing 382. Geraldton
# Processing 383. Lüneburg
# City Unknown. Skipping...
# Processing 384. Meadow Lake
# City Unknown. Skipping...
# Processing 385. Olhão
# Processing 386. Lakshmeshwar
# Processing 387. Port-Cartier
# Processing 388. Teluk Anson
# Processing 389. Loviisa
# Processing 390. Sri Aman
# Processing 391. Orahovac
# Processing 392. Chui
# City Unknown. Skipping...
# City Unknown. Skipping...
# Processing 393. Aasiaat
# Processing 394. Gold Coast
# City Unknown. Skipping...
# Processing 395. Pecos
# Processing 396. Ocampo
# Processing 397. Shelburne
# Processing 398. Timrå
# Processing 399. Necochea
# Processing 400. Guna
# Processing 401. Namatanai
# Processing 402. Kavaratti
# Processing 403. Yeppoon
# Processing 404. Pevek
# Processing 405. Sarangani
# Processing 406. Diego de Almagro
# Processing 407. Siderno
# Processing 408. Catió
# Processing 409. Saint George
# Processing 410. Van
# Processing 411. Shaki
# Processing 412. Jardim
# Processing 413. Olafsvik
# Processing 414. Nhulunbuy
# Processing 415. Visnes
# Processing 416. Mettur
# Processing 417. Nouakchott
# Processing 418. Jumla
# Processing 419. Callaway
# Processing 420. La Palma
# Processing 421. Koryazhma
# Processing 422. Kayes
# Processing 423. Hambantota
# Processing 424. Belyy Yar
# Processing 425. Akdepe
# Processing 426. Sabang
# Processing 427. Killybegs
# Processing 428. Najrān
# Processing 429. Pemba
# City Unknown. Skipping...
# Processing 430. Rio Grande
# Processing 431. Plettenberg Bay
# City Unknown. Skipping...
# Processing 432. Tayoltita
# Processing 433. Arlit
# Processing 434. Kayamkulam
# Processing 435. Santa Rosa
# Processing 436. Margate
# Processing 437. Savannah Bight
# Processing 438. Abu Samrah
# Processing 439. Yerbogachën
# Processing 440. Saldanha
# Processing 441. Angoche
# Processing 442. Kudahuvadhoo
# Processing 443. San Jose
# City Unknown. Skipping...
# Processing 444. Moose Factory
# Processing 445. Santa Maria
# Processing 446. Gazojak
# Processing 447. Okhotsk
# Processing 448. Sursee
# Processing 449. Valday
# Processing 450. Puerto Escondido
# Processing 451. Vardø
# Processing 452. Fukuechō
# Processing 453. Karratha
# Processing 454. Port-Gentil
# Processing 455. Tomatlán
# Processing 456. St. George's
# City Unknown. Skipping...
# City Unknown. Skipping...
# City Unknown. Skipping...
# Processing 457. Marion
# Processing 458. Sturgeon Bay
# Processing 459. Huntsville
# Processing 460. Vila do Maio
# Processing 461. Isiro
# Processing 462. Limulunga
# Processing 463. Bay Roberts
# Processing 464. Waipawa
# Processing 465. Novy Urengoy
# Processing 466. Northam
# Processing 467. Semīrom
# Processing 468. Atasū
# Processing 469. Banamba
# Processing 470. Khabary
# Processing 471. Kieta
# City Unknown. Skipping...
# Processing 472. Sept-Îles
# Processing 473. Inverness
# Processing 474. Helong
# Processing 475. Upata
# Processing 476. Sittwe
# City Unknown. Skipping...
# Processing 477. Port Keats
# City Unknown. Skipping...
# Processing 478. Namanga
# Processing 479. Mindelo
# Processing 480. Aquiraz
# Processing 481. Ordzhonīkīdze
# Processing 482. Boromo
# City Unknown. Skipping...
# Processing 483. Raja
# Processing 484. Buraidah
# Processing 485. North Platte
# Processing 486. Santa Cruz de la Sierra
# City Unknown. Skipping...
# Processing 487. La Rioja
# Processing 488. Wajima
# Processing 489. Mufulira
# Processing 490. Zhalantun
# Processing 491. Vilcún
# Processing 492. Varhaug
# Processing 493. Jamame
# Processing 494. Banyo
# Processing 495. Palmer
# Processing 496. Trairi
# Processing 497. Hofn
# Processing 498. Campos Altos
# Processing 499. Alice Springs
# Processing 500. Balikpapan
# Processing 501. Xiongyue
# Processing 502. Voznesen'ye
# Processing 503. Pijijiapan
# Processing 504. Carbondale
# Processing 505. Bollnäs
# Processing 506. Whitehorse
# Processing 507. Bushehr
# City Unknown. Skipping...
# Processing 508. Geghamasar
# Processing 509. Barillas
# Processing 510. Chudovo
# Processing 511. Hirara
# Processing 512. Caracolí
# Processing 513. Malabo
# Processing 514. Jagatsinghapur
# Processing 515. Faya
# Processing 516. Chapais
# Processing 517. Kousséri
# City Unknown. Skipping...
# City Unknown. Skipping...
# Processing 518. Broome
# Processing 519. Gizo Government Station
# Processing 520. Laas
# Processing 521. Tambun
# Processing 522. Crépy-en-Valois
# Processing 523. Harboøre
# Processing 524. Yagodnoye
# Processing 525. Kralendijk
# Processing 526. Muzhi
# Processing 527. Dunedin
# City Unknown. Skipping...
# Processing 528. Rio Tuba
# Processing 529. Nokaneng
# Processing 530. Porto-Novo
# Processing 531. Pacific Grove
# Processing 532. Katobu
# Processing 533. Nikki
# City Unknown. Skipping...
# Processing 534. Bariloche
# Processing 535. Mishkino
# Processing 536. Neftçala
# Processing 537. Henties Bay
# Processing 538. Paamiut
# Processing 539. Hengshui
# Processing 540. Roura
# Processing 541. Bafoulabé
# Processing 542. Roquetas de Mar
# Processing 543. Tual
# Processing 544. Rome
# Processing 545. Yuancheng
# Processing 546. Salinópolis
# Processing 547. Camapuã
# Processing 548. Roseburg
# Processing 549. Otterup
# Processing 550. Sioux Lookout
# Processing 551. Boone
# {'coord': {'lon': -92.3335, 'lat': 39.0334},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 294,
#   'feels_like': 293.24,
#   'temp_min': 292.48,
#   'temp_max': 295.04,
#   'pressure': 1016,
#   'humidity': 42},
#  'visibility': 10000,
#  'wind': {'speed': 0.89, 'deg': 161, 'gust': 7.6},
#  'clouds': {'all': 100},
#  'dt': 1621475809,
#  'sys': {'type': 2,
#   'id': 2004384,
#   'country': 'US',
#   'sunrise': 1621421583,
#   'sunset': 1621473532},
#  'timezone': -18000,
#  'id': 4377925,
#  'name': 'Boone',
#  'cod': 200}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame(data)
weather_df.head()
# Out:
#             City  Latitude  Longitude  Max Temp  Humidity  Clouds  \
# 0         Hobart  -42.8794   147.3294    287.66        51      20
# 1  Kazachinskoye   57.6953    93.2761    280.13        52      98
# 2       Denpasar   -8.6500   115.2167    301.96        71      40
# 3      Busselton  -33.6500   115.3333    290.83        62      16
# 4       Lüderitz  -26.6481    15.1594    287.97        83       5
#
#    Wind (in mph) Country        Date
# 0           1.79      AU  1621475103
# 1           5.06      RU  1621475687
# 2           3.47      ID  1621475130
# 3           2.16      AU  1621475248
# 4           2.81      NA  1621475303

# %%
weather_df.to_csv("../output_data/cities.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df[weather_df.Humidity > 100]

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = weather_df['Latitude']
y_values = weather_df['Max Temp']
plt.scatter(x_values,y_values)
plt.title("Latitude vs Max Temp")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = weather_df['Latitude']
y_values = weather_df['Humidity']
plt.scatter(x_values,y_values)
plt.title("Latitude vs Humidity")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = weather_df['Latitude']
y_values = weather_df['Cloudy']
plt.scatter(x_values,y_values)
plt.title("Latitude vs Cloudiness")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = weather_df['Latitude']
y_values = weather_df['Wind (in mph)']
plt.scatter(x_values,y_values)
plt.title("Latitude vs Wind Speed")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (in mph)')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
north = weather_df[weather_df.Latitude >=0]
north.head()

# %%
south = weather_df[weather_df.Latitude <0]
south.head()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north['Latitude']
y_values = north['Max Temp']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
print(regress_values)

# %%
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title("Northern Hemi: Latitude vs Max Temp")

# Show plot
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south['Latitude']
y_values = south['Max Temp']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
print(regress_values)

# %%
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title("Southern Hemi: Latitude vs Max Temp")

# Show plot
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north['Latitude']
y_values = north['Humidity']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
print(regress_values)

# %%
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Northern Hemi: Latitude vs Humidity")

# Show plot
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south['Latitude']
y_values = south['Humidity']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
print(regress_values)

# %%
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Southern Hemi: Latitude vs Humidity")

# Show plot
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north['Latitude']
y_values = north['Cloudy']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
print(regress_values)

# %%
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudy')
plt.title("Northern Hemi: Latitude vs Cloudiness")

# Show plot
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south['Latitude']
y_values = south['Cloudy']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
print(regress_values)

# %%
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Southern Hemi: Latitude vs Cloudiness")

# Show plot
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north['Latitude']
y_values = north['Wind (in mph)']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
print(regress_values)

# %%
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (in mph)')
plt.title("Southern Hemi: Latitude vs Wind Speed")

# Show plot
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south['Latitude']
y_values = south['Wind (in mph)']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
print(regress_values)

# %%
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (in mph)')
plt.title("Southern Hemi: Latitude vs Wind Speed")

# Show plot
plt.show()
